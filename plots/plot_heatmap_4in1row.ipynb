# %%
import os
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
PATH_ROOT = Path(os.getcwd()).absolute().parent
print("Root:", PATH_ROOT)
path_output = os.path.join(PATH_ROOT, "results_plot")
print("Output:", path_output)
# Out:
# Root: C:\Users\Behzad\Desktop\KatJupy\diva-data-poisoning
# Output: C:\Users\Behzad\Desktop\KatJupy\diva-data-poisoning\results_plot

# %%
pivot_diff_baseline = pd.read_csv(
    os.path.join(path_output, "heatmap_diff_baseline.csv"), index_col="Poisoning Rate"
)
print(pivot_diff_baseline)
# Out:
#                  Easy  Normal   Hard
# Poisoning Rate
# Clean           100.0    98.0   38.0
# 0.05              0.0    32.0   96.0
# 0.1               0.0    60.0  100.0
# 0.15              4.0    68.0  100.0
# 0.2               8.0    76.0  100.0
# 0.25             14.0    76.0  100.0
# 0.3              18.0    78.0  100.0
# 0.35             18.0    64.0   96.0
# 0.4              20.0    58.0   88.0

# %%
pivot_diff_diva = pd.read_csv(
    os.path.join(path_output, "heatmap_diff_diva.csv"), index_col="Poisoning Rate"
)
print(pivot_diff_diva)
# Out:
#                  Easy  Normal  Hard
# Poisoning Rate
# Clean           100.0    98.0  72.0
# 0.05              0.0    10.0  48.0
# 0.1               0.0    34.0  68.0
# 0.15              2.0    48.0  78.0
# 0.2              18.0    62.0  80.0
# 0.25             24.0    66.0  82.0
# 0.3              40.0    72.0  86.0
# 0.35             42.0    70.0  86.0
# 0.4              48.0    72.0  88.0

# %%
pivot_noise_baseline = pd.read_csv(
    os.path.join(path_output, "heatmap_noise_baseline.csv"), index_col="Poisoning Rate"
)
print(pivot_noise_baseline)
# Out:
#                  0.0  0.05   0.1  0.15   0.2  0.25   0.3  0.35   0.4
# Poisoning Rate
# Clean           98.0  96.0  94.0  88.0  88.0  74.0  68.0  52.0  46.0
# 0.05            14.0  24.0  24.0  32.0  44.0  48.0  52.0  68.0  70.0
# 0.1             30.0  40.0  44.0  52.0  60.0  62.0  70.0  78.0  78.0
# 0.15            40.0  48.0  56.0  60.0  68.0  68.0  74.0  76.0  82.0
# 0.2             48.0  56.0  60.0  56.0  70.0  72.0  76.0  76.0  80.0
# 0.25            44.0  52.0  56.0  58.0  72.0  64.0  72.0  72.0  74.0
# 0.3             40.0  52.0  48.0  52.0  58.0  56.0  60.0  60.0  64.0
# 0.35            36.0  40.0  36.0  36.0  42.0  36.0  36.0  36.0  38.0
# 0.4             32.0  32.0  24.0  22.0  28.0  20.0  24.0  24.0  24.0

# %%
pivot_noise_diva = pd.read_csv(
    os.path.join(path_output, "heatmap_noise_diva.csv"), index_col="Poisoning Rate"
)
print(pivot_noise_diva)
# Out:
#                  0.0  0.05   0.1  0.15   0.2  0.25   0.3  0.35   0.4
# Poisoning Rate
# Clean           98.0  94.0  88.0  76.0  72.0  66.0  54.0  50.0  50.0
# 0.05            12.0  20.0  24.0  36.0  40.0  48.0  52.0  54.0  52.0
# 0.1             28.0  38.0  46.0  50.0  52.0  52.0  56.0  56.0  54.0
# 0.15            36.0  50.0  54.0  58.0  60.0  58.0  60.0  60.0  60.0
# 0.2             52.0  58.0  56.0  62.0  60.0  60.0  60.0  64.0  64.0
# 0.25            50.0  64.0  60.0  64.0  66.0  64.0  62.0  68.0  64.0
# 0.3             64.0  66.0  68.0  68.0  70.0  68.0  64.0  70.0  66.0
# 0.35            62.0  68.0  66.0  66.0  72.0  70.0  70.0  72.0  70.0
# 0.4             66.0  66.0  74.0  74.0  74.0  70.0  74.0  76.0  68.0

# %%
FONTSIZE = 13
FIGSIZE = (11, 3)
TITLES = [
    "(a) Diffic. - Baseline",
    "(b) Diffic. - DIVA",
    "(c) Noise - Baseline",
    "(d) Noise - DIVA",
]
CMAP = "RdYlGn"

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = FONTSIZE
fig, axes = plt.subplots(
    1, 4, sharey=True, figsize=FIGSIZE, gridspec_kw={"width_ratios": [1, 1, 1.6, 1.6]}
)

sns.heatmap(
    pivot_diff_baseline,
    ax=axes[0],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[0].set_ylabel("Poisoning Rate")

sns.heatmap(
    pivot_diff_diva,
    ax=axes[1],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
sns.heatmap(
    pivot_noise_baseline,
    ax=axes[2],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
sns.heatmap(
    pivot_noise_diva,
    ax=axes[3],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)

for i in range(1, 4):
    axes[i].set_ylabel("")

for i, ax in enumerate(axes):
    ax.set(xlabel=None)
    ax.set_title(TITLES[i])

axes[3].set_xticks(axes[2].get_xticks())
axes[3].set_xticklabels(axes[2].get_xticklabels())
# for tick in axes[3].get_xticklabels():
#     tick.set_rotation(90)

# for i in [0, 1]:
#     axes[i].set_xlabel("Difficulty")

for i in [2, 3]:
    axes[i].set_xlabel("Noise Rate")


plt.tight_layout(pad=0.8)
plot_heatmap = os.path.join(path_output, "synth_heatmap_4in1row.svg")
plt.savefig(plot_heatmap, dpi=300)
print(f"Save to: {plot_heatmap}")
# Out:
# Save to: c:\Users\lukex\workspace\diva_01\results_plot\synth_heatmap_4in1row.svg

# %%
import matplotlib
def lighten_color(color, amount=0.5):
    """
    Lightens the given color by multiplying (1-luminosity) by the given amount.
    Input can be matplotlib color string, hex string, or RGB tuple.

    Examples:
    >> lighten_color('g', 0.3)
    >> lighten_color('#F034A3', 0.6)
    >> lighten_color((.3,.55,.1), 0.5)
    """
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], 1 - amount * (1 - c[1]), c[2])

COLORS = {'green': '#2e7d32',
         'yellow': 'yellow',
         'red': '#d32f2f'}
CMAPS = {'green': matplotlib.colors.LinearSegmentedColormap.from_list("", [COLORS['green'], 'white'], N=256),
        'bi': matplotlib.colors.LinearSegmentedColormap.from_list("", [COLORS['red'], 'white', COLORS['green']], N=256),
        'tri': matplotlib.colors.LinearSegmentedColormap.from_list("", [COLORS['red'], COLORS['yellow'], COLORS['green']], N=256),
        'tri_lite': matplotlib.colors.LinearSegmentedColormap.from_list("", [lighten_color(COLORS['red'], 0.8), 
                                                                            lighten_color(COLORS['yellow'], 0.3),
                                                                            lighten_color(COLORS['green'], 0.9)], N=256),
}

# %%
FONTSIZE = 13
FIGSIZE = (8.5, 3)
ANNOT_FONTSIZE = 10
TITLES = [
    "Difficulty\nBaseline",
    "Difficulty\nDIVA",
    "Noise\nBaseline",
    "Noise\nDIVA",
]
CMAP = CMAPS['tri_lite']

sns.set_style("ticks", rc={"font.size": 11})
plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.size": 13})
fig, axes = plt.subplots(
    1, 4, sharey=True, figsize=FIGSIZE, gridspec_kw={"width_ratios": [1, 1, 1.7, 1.7]}
)

sns.heatmap(
    pivot_diff_baseline,
    ax=axes[0],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
    annot_kws={"fontsize":ANNOT_FONTSIZE}
)
axes[0].set_ylabel("Poisoning Rate")

sns.heatmap(
    pivot_diff_diva,
    ax=axes[1],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
    annot_kws={"fontsize":ANNOT_FONTSIZE}
)
sns.heatmap(
    pivot_noise_baseline,
    ax=axes[2],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
    annot_kws={"fontsize":ANNOT_FONTSIZE}
)
sns.heatmap(
    pivot_noise_diva,
    ax=axes[3],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
    annot_kws={"fontsize":ANNOT_FONTSIZE}
)

for i in range(1, 4):
    axes[i].set_ylabel("")

for i, ax in enumerate(axes):
    ax.set(xlabel=None)
    ax.set_title(TITLES[i])

axes[3].set_xticks(axes[2].get_xticks())
axes[3].set_xticklabels(axes[2].get_xticklabels())
# for tick in axes[3].get_xticklabels():
#     tick.set_rotation(90)

# for i in [0, 1]:
#     axes[i].set_xlabel("Difficulty")

for i in [2, 3]:
    axes[i].set_xlabel("Noise Rate")


plt.tight_layout(pad=0.8)
plot_heatmap = os.path.join(path_output, "synth_heatmap_4in1row.pdf")
plt.savefig(plot_heatmap, dpi=300)
print(f"Save to: {plot_heatmap}")
# Out:
# Save to: C:\Users\Behzad\Desktop\KatJupy\diva-data-poisoning\results_plot\synth_heatmap_4in1row.pdf

# %%
pivot_diff_baseline.transpose()
# Out:
# Poisoning Rate  Clean  0.05    0.1   0.15    0.2   0.25    0.3  0.35   0.4
# Easy            100.0   0.0    0.0    4.0    8.0   14.0   18.0  18.0  20.0
# Normal           98.0  32.0   60.0   68.0   76.0   76.0   78.0  64.0  58.0
# Hard             38.0  96.0  100.0  100.0  100.0  100.0  100.0  96.0  88.0

# %%
sns.set_style("ticks", rc={"font.size": 11})
plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.size": 13})
FIGSIZE = (8, 3)
TITLES = [
    "Difficulty - Baseline",
    "Difficulty - DIVA",
    "Noise - Baseline",
    "Noise - DIVA",
]
CMAP = CMAPS['tri_lite']

fig, axes = plt.subplots(1, 2, sharey=True, figsize=FIGSIZE)

sns.heatmap(
    pivot_diff_baseline,
    ax=axes[0],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[0].set_ylabel("Poisoning Rate")
axes[0].set_title(TITLES[0])
axes[0].set_xlabel("Difficulty")

sns.heatmap(
    pivot_diff_diva,
    ax=axes[1],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[1].set_ylabel("")
axes[1].set_title(TITLES[1])
axes[1].set_xlabel("Difficulty")

plt.tight_layout(pad=0.8)
plot_heatmap = os.path.join(path_output, "synth_heatmap_difficulty.pdf")
plt.savefig(plot_heatmap, dpi=300)
print(f"Save to: {plot_heatmap}")
plt.show()

#######################################

fig, axes = plt.subplots(1, 2, sharey=True, figsize=FIGSIZE)

sns.heatmap(
    pivot_noise_baseline,
    ax=axes[0],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[0].set_ylabel("Poisoning Rate")
axes[0].set_title(TITLES[2])
axes[0].set_xlabel("Noise Rate")

sns.heatmap(
    pivot_noise_diva,
    ax=axes[1],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[1].set_ylabel("")
axes[1].set_title(TITLES[3])
axes[1].set_xlabel("Noise Rate")

axes[1].set_xticks(axes[0].get_xticks())
axes[1].set_xticklabels(axes[0].get_xticklabels())


plt.tight_layout(pad=0.8)
plot_heatmap = os.path.join(path_output, "synth_heatmap_noise.pdf")
plt.savefig(plot_heatmap, dpi=300)
print(f"Save to: {plot_heatmap}")
plt.show()
# Out:
# Save to: C:\Users\Behzad\Desktop\KatJupy\diva-data-poisoning\results_plot\synth_heatmap_difficulty.pdf
# Save to: C:\Users\Behzad\Desktop\KatJupy\diva-data-poisoning\results_plot\synth_heatmap_noise.pdf

# %%
sns.set_style("ticks", rc={"font.size": 11})
plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.size": 14, "xtick.labelsize": 12, "ytick.labelsize": 12})

FIGSIZE = (6, 3)
TITLES = [
    "Difficulty - Baseline",
    "Difficulty - DIVA",
    "Noise - Baseline",
    "Noise - DIVA",
]
CMAP = CMAPS['tri_lite']

fig, axes = plt.subplots(2, 2, sharex=True, figsize=(8, 5), gridspec_kw={"height_ratios": [0.4,1]})

sns.heatmap(
    pivot_diff_baseline.transpose(),
    ax=axes[0,0],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[0,0].set_xlabel("")
axes[0,0].set_title(TITLES[0])
axes[0,0].set_ylabel("Difficulty", labelpad=1)
axes[0,0].vlines(1, *axes[0,0].get_ylim(), color='white', lw=3)

sns.heatmap(
    pivot_diff_diva.transpose(),
    ax=axes[0,1],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[0,1].set_xlabel("")
axes[0,1].set_title(TITLES[1])
axes[0,1].set_ylabel("")
axes[0,1].set_yticklabels([])
axes[0,1].vlines(1, *axes[0,1].get_ylim(), color='white', lw=3)

sns.heatmap(
    pivot_noise_baseline.transpose(),
    ax=axes[1,0],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[1,0].set_xlabel("Poisoning Rate")
axes[1,0].set_title(TITLES[2])
axes[1,0].set_ylabel("Noise Rate", labelpad=20)
axes[1,0].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0) 
axes[1,0].vlines(1, *axes[1,0].get_ylim(), color='white', lw=3)

sns.heatmap(
    pivot_noise_diva.transpose(),
    ax=axes[1,1],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[1,1].set_xlabel("Poisoning Rate")
axes[1,1].set_title(TITLES[3])
axes[1,1].set_ylabel("")
axes[1,1].set_yticklabels([])

axes[1,1].set_xticks(axes[1,0].get_xticks())
axes[1,1].set_xticklabels(axes[1,0].get_xticklabels())
axes[1,1].vlines(1, *axes[1,1].get_ylim(), color='white', lw=3)


plt.tight_layout(pad=0.8)
fig.subplots_adjust(hspace=0.3, wspace=0.1)
plot_heatmap = os.path.join(path_output, "synth_heatmap_2x2.pdf")
plt.savefig(plot_heatmap, dpi=300)
print(f"Save to: {plot_heatmap}")
plt.show()
# Out:
# Save to: C:\Users\Behzad\Desktop\KatJupy\diva-data-poisoning\results_plot\synth_heatmap_2x2.pdf

# %%
pivot_diff_baseline = pd.read_csv(
    os.path.join(path_output, "heatmap_diff_baseline.csv"), index_col="Poisoning Rate", names=['Poisoning Rate', 'E', 'N', 'H'], header=0
)
pivot_diff_diva = pd.read_csv(
    os.path.join(path_output, "heatmap_diff_diva.csv"), index_col="Poisoning Rate", names=['Poisoning Rate', 'E', 'N', 'H'], header=0
)

# %%
sns.set_style("ticks")
plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.size": 9, "xtick.labelsize": 11, 
                     "ytick.labelsize": 11, "axes.titlesize": 14, "axes.labelsize": 11})
TITLESIZE = 14

TITLES = [
    "Difficulty - Baseline",
    "Difficulty - DIVA",
    "Noise - Baseline",
    "Noise - DIVA",
]
CMAP = CMAPS['tri_lite']
sep_col = 'black'

fig, axes = plt.subplots(2, 2, sharex=True, figsize=(5, 3.5), gridspec_kw={"height_ratios": [0.4,1]})

sns.heatmap(
    pivot_diff_baseline.transpose(),
    ax=axes[0,0],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[0,0].set_xlabel("")
axes[0,0].set_title(TITLES[0], fontsize=TITLESIZE)
axes[0,0].set_ylabel("Difficulty", labelpad=13.5)
axes[0,0].set_yticklabels(axes[0,0].get_yticklabels(), rotation=0) 
axes[0,0].vlines(1, *axes[0,0].get_ylim(), color=sep_col, lw=3)

sns.heatmap(
    pivot_diff_diva.transpose(),
    ax=axes[0,1],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[0,1].set_xlabel("")
axes[0,1].set_title(TITLES[1], fontsize=TITLESIZE)
axes[0,1].set_ylabel("")
axes[0,1].set_yticklabels([])
axes[0,1].vlines(1, *axes[0,1].get_ylim(), color=sep_col, lw=3)

sns.heatmap(
    pivot_noise_baseline.transpose(),
    ax=axes[1,0],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[1,0].set_xlabel("Poisoning Rate")
axes[1,0].set_title(TITLES[2], fontsize=TITLESIZE)
axes[1,0].set_ylabel("Noise Rate", labelpad=1)
axes[1,0].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0) 
axes[1,0].vlines(1, *axes[1,0].get_ylim(), color=sep_col, lw=3)

for lab in axes[1,0].get_xticklabels():
    if lab.get_text() == "Clean":
        lab.set_fontweight('bold')

sns.heatmap(
    pivot_noise_diva.transpose(),
    ax=axes[1,1],
    annot=True,
    fmt=".0f",
    cmap=CMAP,
    vmin=0,
    vmax=100,
    cbar=False,
)
axes[1,1].set_xlabel("Poisoning Rate")
axes[1,1].set_title(TITLES[3], fontsize=TITLESIZE)
axes[1,1].set_ylabel("")
axes[1,1].set_yticklabels([])

axes[1,1].set_xticks(axes[1,0].get_xticks())
axes[1,1].set_xticklabels(axes[1,0].get_xticklabels())
axes[1,1].vlines(1, *axes[1,1].get_ylim(), color=sep_col, lw=3)


plt.tight_layout()#(pad=0.8)
fig.subplots_adjust(hspace=0.4, wspace=0.1)
plot_heatmap = os.path.join(path_output, "synth_heatmap_2x2.pdf")
plt.savefig(plot_heatmap, dpi=300)
print(f"Save to: {plot_heatmap}")
plt.show()
# Out:
# Save to: C:\Users\Behzad\Desktop\KatJupy\diva-data-poisoning\results_plot\synth_heatmap_2x2.pdf
